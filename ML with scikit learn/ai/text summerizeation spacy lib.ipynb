# %%
import spacy

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
print("Model loaded successfully ✅")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 3
#       1 import spacy
# ----> 3 nlp = spacy.load("en_core_web_sm")
#       4 print("Model loaded successfully ✅")
#
# File ~\anaconda3\Lib\site-packages\spacy\__init__.py:74, in load(name, vocab, disable, enable, exclude, config)
#      50 def load(
#      51     name: Union[str, Path],
#      52     *,
#    (...)     57     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      58 ) -> Language:
#      59     """Load a spaCy model from an installed package or a local path.
#      60
#      61     name (str): Package name or model path.
#    (...)     72     RETURNS (Language): The loaded nlp object.
#      73     """
# ---> 74     return util.load_model(
#      75         name,
#      76         vocab=vocab,
#      77         disable=disable,
#      78         enable=enable,
# ...

# %%
import en_core_web_sm

nlp = en_core_web_sm.load()

doc = nlp("Google is opening an office in India")

for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import en_core_web_sm
#       3 nlp = en_core_web_sm.load()
#       5 doc = nlp("Google is opening an office in India")
#
# ModuleNotFoundError: No module named 'en_core_web_sm'
